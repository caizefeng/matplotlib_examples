# %% [markdown]
# ### Annotations

# %% [markdown]
# #### Adding text

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 1000)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, np.cos(x), c='g', alpha=0.5)
plt.show()
